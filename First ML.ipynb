# %%
#Pandas
import pandas as pd
#Importing ML model (Decision Tree)
from sklearn.tree import DecisionTreeRegressor
#Importing Model Evalution Module
from sklearn.metrics import mean_absolute_error
#Import Model DataSet Split Trainer
from sklearn.model_selection import train_test_split
#Random Forest Model to 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
hd = pd.read_csv('C:/Users/91959/Desktop/Housing Data/train.csv')
hd
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
hd.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
hd.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
hd = hd.drop(['Alley','MiscFeature','PoolQC','Fence'],axis=1)

# %%
hd.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
for i in hd.columns:
    print(i)
    print(hd[i].isna().sum())
# Out:
# Id
# 0
# MSSubClass
# 0
# MSZoning
# 0
# LotArea
# 0
# Street
# 0
# LotShape
# 0
# LandContour
# 0
# Utilities
# 0
# LotConfig
# 0
# LandSlope
# 0
# Neighborhood
# 0
# Condition1
# 0
# Condition2
# 0
# BldgType
# 0
# HouseStyle
# 0
# OverallQual
# 0
# OverallCond
# 0
# YearBuilt
# 0
# YearRemodAdd
# 0
# RoofStyle
# 0
# RoofMatl
# 0
# Exterior1st
# 0
# Exterior2nd
# 0
# MasVnrType
# 8
# MasVnrArea
# 8
# ExterQual
# 0
# ExterCond
# 0
# Foundation
# 0
# BsmtQual
# 37
# BsmtCond
# 37
# BsmtExposure
# 38
# BsmtFinType1
# 37
# BsmtFinSF1
# 0
# BsmtFinType2
# 38
# BsmtFinSF2
# 0
# BsmtUnfSF
# 0
# TotalBsmtSF
# 0
# Heating
# 0
# HeatingQC
# 0
# CentralAir
# 0
# Electrical
# 1
# 1stFlrSF
# 0
# 2ndFlrSF
# 0
# LowQualFinSF
# 0
# GrLivArea
# 0
# BsmtFullBath
# 0
# BsmtHalfBath
# 0
# FullBath
# 0
# HalfBath
# 0
# BedroomAbvGr
# 0
# KitchenAbvGr
# 0
# KitchenQual
# 0
# TotRmsAbvGrd
# 0
# Functional
# 0
# Fireplaces
# 0
# GarageType
# 81
# GarageYrBlt
# 81
# GarageFinish
# 81
# GarageCars
# 0
# ...

# %%
hd = hd.drop(['FireplaceQu'],axis=1)

# %%
hd = hd.drop(['LotFrontage'],axis=1)

# %%
hd.loc[0:1460]
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# ...

# %%
for i in range(len(hd)):
    print("i: ",i)
    print(hd.loc[i].isna().sum())
# Out:
# i:  0
# 0
# i:  1
# 0
# i:  2
# 0
# i:  3
# 0
# i:  4
# 0
# i:  5
# 0
# i:  6
# 0
# i:  7
# 0
# i:  8
# 0
# i:  9
# 0
# i:  10
# 0
# i:  11
# 0
# i:  12
# 0
# i:  13
# 0
# i:  14
# 0
# i:  15
# 0
# i:  16
# 0
# i:  17
# 5
# i:  18
# 0
# i:  19
# 0
# i:  20
# 0
# i:  21
# 0
# i:  22
# 0
# i:  23
# 0
# i:  24
# 0
# i:  25
# 0
# i:  26
# 0
# i:  27
# 0
# i:  28
# 0
# i:  29
# 0
# i:  30
# 0
# i:  31
# 0
# i:  32
# 0
# i:  33
# 0
# i:  34
# 0
# i:  35
# 0
# i:  36
# 0
# i:  37
# 0
# i:  38
# 0
# i:  39
# 10
# i:  40
# 0
# i:  41
# 0
# i:  42
# 0
# i:  43
# 0
# i:  44
# 0
# i:  45
# 0
# i:  46
# 0
# i:  47
# 0
# i:  48
# 5
# i:  49
# 0
# i:  50
# 0
# i:  51
# 0
# i:  52
# 0
# i:  53
# 0
# i:  54
# 0
# i:  55
# 0
# i:  56
# 0
# i:  57
# 0
# i:  58
# 0
# i:  59
# 0
# i:  60
# 0
# i:  61
# 0
# i:  62
# 0
# i:  63
# 0
# i:  64
# 0
# i:  65
# 0
# i:  66
# 0
# i:  67
# 0
# i:  68
# 0
# i:  69
# 0
# i:  70
# 0
# i:  71
# 0
# i:  72
# 0
# i:  73
# 0
# i:  74
# 0
# i:  75
# 0
# i:  76
# 0
# ...

# %%
hd.loc[[78,88],:]
# Out:
#     Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 78  79          90       RL    10778   Pave      Reg         Lvl    AllPub
# 88  89          50  C (all)     8470   Pave      IR1         Lvl    AllPub
#
#    LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 78    Inside       Gtl       Sawyer       Norm       Norm   Duplex     1Story
# 88    Corner       Gtl       IDOTRR      Feedr      Feedr     1Fam     1.5Fin
#
#     OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 78            4            5       1968          1968       Hip  CompShg
# 88            3            2       1915          1982       Hip  CompShg
#
#    Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 78     HdBoard     HdBoard       None         0.0        TA        TA
# 88     Plywood     Plywood       None         0.0        Fa        Fa
#
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
hd
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# ...

# %% [markdown]
# #### FEATURE SELECTION

# %%
hd.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
hd = hd.dropna()

# %%
hd.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
y = hd.SalePrice

# %%
y.describe()
# Out:
# count      1338.000000
# mean     186761.782511
# std       78913.847668
# min       35311.000000
# 25%      135000.000000
# 50%      168500.000000
# 75%      220000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
features = ['YearBuilt','OverallCond','YearRemodAdd','OverallQual','YrSold','1stFlrSF','2ndFlrSF']

# %%
features
# Out:
# ['YearBuilt',
#  'OverallCond',
#  'YearRemodAdd',
#  'OverallQual',
#  'YrSold',
#  '1stFlrSF',
#  '2ndFlrSF']

# %%
X = hd[features]

# %%
X #TRAINING VARIABLES
# Out:
#       YearBuilt  OverallCond  YearRemodAdd  OverallQual  YrSold  1stFlrSF  \
# 0          2003            5          2003            7    2008       856
# 1          1976            8          1976            6    2007      1262
# 2          2001            5          2002            7    2008       920
# 3          1915            5          1970            7    2006       961
# 4          2000            5          2000            8    2008      1145
# ...         ...          ...           ...          ...     ...       ...
# 1455       1999            5          2000            6    2007       953
# 1456       1978            6          1988            6    2010      2073
# 1457       1941            9          2006            7    2010      1188
# 1458       1950            6          1996            5    2010      1078
# 1459       1965            6          1965            5    2008      1256
#
#       2ndFlrSF
# 0          854
# 1            0
# 2          866
# ...

# %%
y #PREDICTION TARGET
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1338, dtype: int64

# %% [markdown]
# ### MODEL BUILDING (DECISION TREE)

# %%
hd_model = DecisionTreeRegressor(random_state=1)
hd_model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print('Predicting: ')
print(X.head())
# Out:
# Predicting:
#    YearBuilt  OverallCond  YearRemodAdd  OverallQual  YrSold  1stFlrSF  \
# 0       2003            5          2003            7    2008       856
# 1       1976            8          1976            6    2007      1262
# 2       2001            5          2002            7    2008       920
# 3       1915            5          1970            7    2006       961
# 4       2000            5          2000            8    2008      1145
#
#    2ndFlrSF
# 0       854
# 1         0
# 2       866
# 3       756
# 4      1053

# %%
hd_predicted = hd_model.predict(X)
hd_predicted
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %%
print("On average, the predictions are off by about: ",mean_absolute_error(y,hd_predicted))
# Out:
# On average, the predictions are off by about:  44.130044843049326

# %%
#Sample Test
hd_model.predict([[2022,8,2022,7,2022,1262,1262]])
# Out:
# array([383970.])

# %% [markdown]
# ### AVOIDING INSAMPLE MODEL EVALUATION

# %%
#RANDOM SPLITTING THE DATA SET FOR TRAINING AND .
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
#NEW MODEL.
hd2_model = DecisionTreeRegressor(random_state=0)
#TRAIN MODEL.
hd2_model.fit(train_X,train_y)
#PREDICT USING SPLIT DATA.
val_predictions = hd2_model.predict(val_X)
#MEAN ABSOLUTE ERROR OF SPLIT DATA.
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 27143.09154228856

# %%
#TREE DEPTH CONTROL TO FIX UNDER/OVER FITTING.
###MAX_LEAF_NODES - ARGUMENT OF DecisionTreeRegressor Function.
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  33461
# Max leaf nodes: 50  		 Mean Absolute Error:  24198
# Max leaf nodes: 500  		 Mean Absolute Error:  27453
# Max leaf nodes: 5000  		 Mean Absolute Error:  27683

# %% [markdown]
# ### RANDOM FORESTS

# %%
## BETTER RESULT THAN PREVIOUS METHOD (ADJUSTING TREE HEIGHT)
forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
hd_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, hd_preds))
# Out:
# 20593.894860199005
